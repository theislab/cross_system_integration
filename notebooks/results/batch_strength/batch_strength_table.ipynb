# %%
import pandas as pd
import pickle as pkl

# %%
path_data='/om2/user/khrovati/data/cross_system_integration/'
path_names=path_data+'names_parsed/'
path_tables=path_data+'tables/'

# %%
dataset_map=pkl.load(open(path_names+'datasets.pkl','rb'))
system_map=pkl.load(open(path_names+'systems.pkl','rb'))
cell_type_map=pkl.load(open(path_names+'cell_types.pkl','rb'))

# %%
# Load results
dataset_metric_fns={
    'pancreas_conditions_MIA_HPAP2':'combined_orthologuesHVG',
    'retina_adult_organoid':'combined_HVG',
    'adipose_sc_sn_updated':'adiposeHsSAT_sc_sn',
}
writer = pd.ExcelWriter(path_tables+'PcaSysBatchDist_Signif.xlsx',engine='xlsxwriter') 
for dataset,fn_part in dataset_metric_fns.items():
    table_sub=pd.read_table(f'{path_data}{dataset}/{fn_part}_PcaSysBatchDist_Signif.tsv')
    table_sub['cell_type']=table_sub['cell_type'].map(cell_type_map[dataset])
    table_sub['system']=table_sub['system'].\
        str.replace('s0',system_map[dataset]['0']).\
        str.replace('s1',system_map[dataset]['1'])
    dataset_name=dataset_map[dataset]
    table_sub.to_excel(writer, sheet_name=dataset_name,index=False)   
    print(dataset_name)
    display(table_sub) 
writer.close()
# Out:
# Mouse-Human
#         cell_type         system        u           pval  n_system  \
# 0   Endo. prolif.   Mouse_within      0.0   1.031992e-03         3
# 1   Endo. prolif.  Mouse_between      0.0   1.031992e-03         3
# 2   Endo. prolif.          Human      6.0   4.020747e-04         6
# 3            Beta   Mouse_within      0.0  6.579697e-128       205
# 4            Beta  Mouse_between    712.0   0.000000e+00      1121
# 5            Beta          Human     20.0   0.000000e+00      1830
# 6          Acinar   Mouse_within      0.0   9.952913e-07         3
# 7          Acinar          Human  36533.0   1.533455e-65      1770
# 8           Delta   Mouse_within      0.0   1.629970e-92       166
# 9           Delta  Mouse_between   1159.0  2.804222e-298      1010
# 10          Delta          Human      1.0   1.771875e-78       136
# 11          Gamma   Mouse_within      0.0   1.418489e-47       103
# 12          Gamma  Mouse_between      0.0  3.983218e-102       527
# 13          Gamma          Human      0.0   4.875664e-11        15
# 14         Immune   Mouse_within  10438.0   4.820733e-22        88
# 15         Immune  Mouse_between  97668.0   2.901453e-12       408
# 16         Immune          Human  16627.0   1.261008e-52       190
# 17    Stellate a.   Mouse_within      0.0   6.764710e-41        63
# 18    Stellate a.  Mouse_between  13389.0   4.620897e-91       213
# 19    Stellate a.          Human     60.0   0.000000e+00       903
# 20          Alpha   Mouse_within      0.0  6.579697e-128       205
# 21          Alpha  Mouse_between      0.0   0.000000e+00      1121
# 22          Alpha          Human    611.0   0.000000e+00      1830
# 23    Stellate q.   Mouse_within      2.0   8.045640e-37        61
# 24    Stellate q.  Mouse_between    571.0   1.746329e-78       170
# 25    Stellate q.          Human      2.0   2.564254e-81       171
# 26     Alpha+Beta   Mouse_within      0.0   8.512087e-06         3
# 27     Alpha+Beta          Human      0.0   7.185159e-49       406
# 28    Endothelial   Mouse_within      0.0   1.908662e-53        87
# 29    Endothelial  Mouse_between   3707.0  3.480803e-143       319
# 30    Endothelial          Human     98.0  3.069273e-170       378
# 31         Ductal   Mouse_within      0.0   2.644989e-34        52
# 32         Ductal  Mouse_between      0.0   8.740909e-62       101
# 33         Ductal          Human      0.0   0.000000e+00      1378
#
#     n_crossystem           padj
# 0             16   1.031992e-03
# 1             16   1.031992e-03
# 2             16   4.272044e-04
# 3           3172  2.033725e-127
# 4           3172   0.000000e+00
# 5           3172   0.000000e+00
# 6            180   1.127997e-06
# 7            180   2.896526e-65
# 8            833   4.262999e-92
# 9            833  1.362051e-297
# 10           833   3.543749e-78
# 11           216   2.096897e-47
# 12           216  1.128578e-101
# 13           216   5.716295e-11
# 14           640   6.070553e-22
# 15           640   3.523193e-12
# 16           640   2.041632e-52
# 17          1032   9.583339e-41
# 18          1032   1.122218e-90
# 19          1032   0.000000e+00
# 20          3172  2.033725e-127
# 21          3172   0.000000e+00
# 22          3172   0.000000e+00
# 23           418   1.094207e-36
# 24           418   3.543749e-78
# 25           418   5.812308e-81
# 26            87   9.335838e-06
# 27            87   1.110434e-48
# 28           812   3.244725e-53
# 29           812  1.314970e-142
# 30           812  1.304441e-169
# 31           954   3.458832e-34
# 32           954   1.564163e-61
# 33           954   0.000000e+00
# Organoid-Tissue
#                  cell_type    system     u          pval  n_system  \
# 0          ON-bipolar cell  Organoid   0.0  2.399227e-13        28
# 1          ON-bipolar cell    Tissue   0.0  3.288052e-09        15
# 2         Rod bipolar cell  Organoid   0.0  1.400560e-04         3
# 3         Rod bipolar cell    Tissue   0.0  2.695407e-15        55
# 4        Retinal cone cell  Organoid   0.0  1.303458e-70       210
# 5        Retinal cone cell    Tissue   0.0  3.409498e-26        45
# 6         Retinal rod cell  Organoid   0.0  7.036008e-74       210
# 7         Retinal rod cell    Tissue   0.0  5.040256e-31        55
# 8   Retina horizontal cell  Organoid  56.0  5.532404e-29        66
# 9   Retina horizontal cell    Tissue   0.0  2.620078e-23        45
# 10           Amacrine cell  Organoid  41.0  1.330027e-20        55
# 11           Amacrine cell    Tissue   0.0  9.151916e-10        15
# 12            Mueller cell  Organoid   0.0  7.036008e-74       210
# 13            Mueller cell    Tissue  16.0  7.056784e-31        55
# 14        OFF-bipolar cell  Organoid   0.0  1.400560e-04         3
# 15        OFF-bipolar cell    Tissue   0.0  2.695407e-15        55
#
#     n_crossystem          padj
# 0             48  3.198970e-13
# 1             48  3.757774e-09
# 2             33  1.400560e-04
# 3             33  3.920592e-15
# 4            210  6.951778e-70
# 5            210  7.793139e-26
# 6            231  5.628807e-73
# 7            231  2.016102e-30
# 8            120  1.475308e-28
# 9            120  5.240155e-23
# 10            66  2.364492e-20
# 11            66  1.126390e-09
# 12           231  5.628807e-73
# 13           231  2.258171e-30
# 14            33  1.400560e-04
# 15            33  3.920592e-15
# Cell-Nuclei
#       cell_type  system     u          pval  n_system  n_crossystem  \
# 0       NK cell    Cell   0.0  4.343483e-06         6            20
# 1       NK cell  Nuclei   0.0  6.004721e-06        10            20
# 2          ASPC    Cell  89.0  3.194510e-16        36            81
# 3          ASPC  Nuclei  80.0  2.062908e-16        36            81
# 4    Macrophage    Cell   6.0  5.718876e-06         6            36
# 5    Macrophage  Nuclei   0.0  1.523170e-13        36            36
# 6   Endothelial    Cell  14.0  2.179505e-06        10            45
# 7   Endothelial  Nuclei  84.0  2.684430e-12        36            45
# 8        T cell    Cell   0.0  9.107229e-12        21            56
# 9        T cell  Nuclei  30.0  4.346527e-13        28            56
# 10     Monocyte    Cell   0.0  1.225490e-03         3            15
# 11     Monocyte  Nuclei   0.0  1.794065e-05        10            15
#
#             padj
# 0   6.515224e-06
# 1   7.205665e-06
# 2   1.916706e-15
# 3   1.916706e-15
# 4   7.205665e-06
# 5   6.092682e-13
# 6   3.736295e-06
# 7   6.442633e-12
# 8   1.821446e-11
# 9   1.303958e-12
# 10  1.225490e-03
# 11  1.957162e-05
